# %%
import json
import asyncio
import nest_asyncio
from typing import List, Dict, Union
from httpx import AsyncClient, Response
from parsel import Selector
from loguru import logger as log
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from tqdm.asyncio import tqdm_asyncio
import traceback
import os

# initialize an async httpx client
client = AsyncClient(
    timeout=30.0,
    http2=True,
    headers={
        "Accept-Language": "en-US,en;q=0.9",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "Accept-Encoding": "gzip, deflate, br",
        "Cookie": "intl_splash=false"
    },
    follow_redirects=True
)


def parse_post_comments(response: Response) -> List[Dict]:
    """parse post comments"""

    def parse_comment(parent_selector) -> Dict:
        """parse a comment object"""
        link = parent_selector.xpath("./@data-permalink").get()
        upvotes = parent_selector.xpath(".//span[contains(@class, 'likes')]/@title").get()      
        return {
            "link": "https://www.reddit.com" + link if link else None,
            "commentBody": parent_selector.xpath(".//div[@class='md']/p/text()").get(),
            "upvotes": int(upvotes) if upvotes else None,          
        }

    def parse_replies(what) -> List[Dict]:
        """recursively parse replies"""
        replies = []
        for reply_box in what.xpath(".//div[@data-type='comment']"):
            reply_comment = parse_comment(reply_box)
            child_replies = parse_replies(reply_box)
            if child_replies:
                reply_comment["replies"] = child_replies
            replies.append(reply_comment)
        return replies

    selector = Selector(response.text)
    data = []
    for item in selector.xpath("//div[@class='sitetable nestedlisting']/div[@data-type='comment']"):
        comment_data = parse_comment(item)
        replies = parse_replies(item)
        if replies:
            comment_data["replies"] = replies
        data.append(comment_data)            
    return data


async def scrape_post(url: str, sort: Union["old", "new", "top"]) -> Dict:
    """scrape subreddit post and comment data"""
    response = await client.get(url)
    post_data = {}
    post_link = url if "old.reddit.com" in url else url.replace("www.reddit.com", "old.reddit.com")
    # scrape the comments from the old.reddit version, with the same post URL 
    bulk_comments_page_url = post_link.replace("www", "old") + f"?sort={sort}&limit=5000"
    response = await client.get(bulk_comments_page_url)
    post_data["comments"] = parse_post_comments(response) 
    log.success(f"scraped {len(post_data['comments'])} comments from the post {url}")
    return post_data

# %%
###Define the function to figure out the ratio of postive to negative comments in each post
nest_asyncio.apply()

analyzer = SentimentIntensityAnalyzer()
semaphore = asyncio.Semaphore(3)  

def flatten_comments(comments):
    flat = []
    def _recurse(comment):
        flat.append(comment)
        for reply in comment.get("replies", []):
            _recurse(reply)
    for comment in comments:
        _recurse(comment)
    return flat


def load_existing_results(path="team_week_sentiment_long.csv"):
    if os.path.exists(path):
        return pd.read_csv(path)
    else:
        return pd.DataFrame(columns=["Team", "Week", "PositiveRatio", "NegativeRatio", "TotalComments"])


def calculate_sentiment_ratios(comments):
    poscount = 0
    negcount = 0
    for comment in comments:
        body = comment.get("commentBody") or ""
        sentiment = analyzer.polarity_scores(body)
        compound = sentiment["compound"]
        if compound < -0.05:
            negcount += 1
        elif compound > 0.05:
            poscount += 1
    total = poscount + negcount
    if total == 0:
        return 0.0, 0.0, 0
    return poscount / total, negcount / total, total

async def analyze_from_csv(csv_path: str):
    df = pd.read_csv(csv_path)
    df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="URL")
    df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
    df_melted = df_melted.dropna(subset=["URL"])

    existing_df = load_existing_results()

    successful_df = existing_df[
    (existing_df["PositiveRatio"] > 0.0) | 
    (existing_df["NegativeRatio"] > 0.0) | 
    (existing_df["TotalComments"] > 0)
]

    existing_keys = set(zip(successful_df["Team"], successful_df["Week"]))

# Filter the melted dataframe to only those not already scraped
    df_to_scrape = df_melted[~df_melted.apply(lambda row: (row["Team"], row["Week"]) in existing_keys, axis=1)]
    print(df_to_scrape.head())


    results = []

    async def process_row(row):
        async with semaphore:
            try:
                team = row["Team"]
                week = row["Week"]
                url = row["URL"]
                print(f"Processing: Team={team}, Week={week}, URL={url}")
                post_data = await scrape_post(url, sort="top")
                comments = flatten_comments(post_data["comments"])
                pos, neg, total = calculate_sentiment_ratios(comments)
                return {
                    "Team": team,
                    "Week": week,
                    "PositiveRatio": pos,
                    "NegativeRatio": neg,
                    "TotalComments": total
                }
            except Exception as e:
                print(f"Failed: {team} {week} -> {e}")
                traceback.print_exc()
                return {
                    "Team": team,
                    "Week": week,
                    "PositiveRatio": 0.0,
                    "NegativeRatio": 0.0,
                    "TotalComments": 0
                }


    tasks = [process_row(row) for _, row in df_to_scrape.iterrows()]
    results = await tqdm_asyncio.gather(*tasks)

    # After getting `results` from scraping:
    new_results_df = pd.DataFrame(results)

    # Combine with old data, drop duplicates
    combined_df = pd.concat([existing_df, new_results_df], ignore_index=True)
    combined_df.drop_duplicates(subset=["Team", "Week"], keep="last", inplace=True)

    # Save updated file
    combined_df.to_csv("team_week_sentiment_long.csv", index=False)
    return combined_df

# %%
### Get the dataset of sentiment
result_df = asyncio.run(analyze_from_csv("NFL 2024-25 Subreddit - Sheet1.csv"))
print(result_df.head())
# Out:
# Empty DataFrame
# Columns: [Team, Week, URL]
# Index: []
# 0it [00:00, ?it/s]
#                  Team    Week  PositiveRatio  NegativeRatio  TotalComments
# 0   Arizona Cardinals  Week 1       0.560079       0.439921           1007
# 1     Atlanta Falcons  Week 1       0.492991       0.507009            428
# 2   Carolina Panthers  Week 1       0.565161       0.434839            775
# 3  Cincinnati Bengals  Week 1       0.529837       0.470163            553
# 4    Cleveland Browns  Week 1       0.585324       0.414676            586

# %%
### Merge to get the full dataset
result_df = pd.read_csv('team_week_sentiment_long.csv')


df = pd.read_csv('NFL 2024-25 Div Games - Sheet1.csv')
df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="Div")
df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
df_melted = df_melted.dropna(subset=["Div"])
merged_df = pd.merge(result_df, df_melted, on=["Team", "Week"], how="left")

df = pd.read_csv('NFL 2024-25 Home - Sheet1.csv')
df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="Home")
df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
df_melted = df_melted.dropna(subset=["Home"])
merged_df = pd.merge(merged_df, df_melted, on=["Team", "Week"], how="left")



df = pd.read_csv('NFL 2024-25 Margins - Sheet1.csv')
df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="Margin of Victory")
df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
df_melted = df_melted.dropna(subset=["Margin of Victory"])
merged_df = pd.merge(merged_df, df_melted, on=["Team", "Week"], how="left")




df = pd.read_csv('NFL 2024-25 Opps - Sheet1.csv')
df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="Opponent")
df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
df_melted = df_melted.dropna(subset=["Opponent"])
merged_df = pd.merge(merged_df, df_melted, on=["Team", "Week"], how="left")



df = pd.read_csv('NFL 2024-25 Playoffs - Sheet1.csv')
df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="Playoff")
df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
df_melted = df_melted.dropna(subset=["Playoff"])
merged_df = pd.merge(merged_df, df_melted, on=["Team", "Week"], how="left")



df = pd.read_csv('NFL 2024-25 Primetime - Sheet1.csv')
df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="Prime Time")
df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
df_melted = df_melted.dropna(subset=["Prime Time"])
merged_df = pd.merge(merged_df, df_melted, on=["Team", "Week"], how="left")


df = pd.read_csv('NFL 2024-25 W-L - Sheet1.csv')
df_melted = df.melt(id_vars=["Unnamed: 0"], var_name="Week", value_name="Win-Lose")
df_melted = df_melted.rename(columns={"Unnamed: 0": "Team"})
df_melted = df_melted.dropna(subset=["Win-Lose"])
merged_df = pd.merge(merged_df, df_melted, on=["Team", "Week"], how="left")

merged_df['Week'] = merged_df['Week'].replace('WIld Card', 'Wild Card')
print(merged_df.head())



merged_df.to_csv("NFL 2024-25 Full.csv", index=False)
# Out:
#                  Team    Week  PositiveRatio  NegativeRatio  TotalComments  \
# 0   Arizona Cardinals  Week 1       0.560079       0.439921           1007
# 1     Atlanta Falcons  Week 1       0.492991       0.507009            428
# 2   Carolina Panthers  Week 1       0.565161       0.434839            775
# 3  Cincinnati Bengals  Week 1       0.529837       0.470163            553
# 4    Cleveland Browns  Week 1       0.585324       0.414676            586
#
#    Div Home  Margin of Victory              Opponent Playoff Prime Time  \
# 0   No   No               -6.0         Buffalo Bills      No         No
# 1   No  Yes               -8.0   Pittsburgh Steelers      No         No
# 2  Yes   No              -37.0    New Orleans Saints      No         No
# 3   No  Yes               -6.0  New England Patriots      No         No
# 4   No  Yes              -16.0        Dallas Cowboys      No         No
#
#   Win-Lose
# 0        L
# 1        L
# 2        L
# 3        L
# 4        L

# %%
####Code to see individual comments

nest_asyncio.apply()

async def run():
    post_data = await scrape_post(
        url = "https://www.reddit.com/r/eagles/comments/1ilwnz0/post_game_thread_super_bowl_champions_the_eagles/",
        sort="top"
    )
    with open("post.json", "w", encoding="utf-8") as file:
        json.dump(post_data, file, indent=2, ensure_ascii=False)


if __name__ == "__main__":
    asyncio.run(run())


import json
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Load the data
with open("post.json", "r", encoding="utf-8") as f:
    data = json.load(f)

comments = data["comments"]


# Initialize VADER
analyzer = SentimentIntensityAnalyzer()

# Flatten all comments including replies
def flatten_comments(comments):
    flat = []

    def _recurse(comment):
        flat.append(comment)
        if "replies" in comment:
            for reply in comment["replies"]:
                _recurse(reply)

    for comment in comments:
        _recurse(comment)
    
    return flat

flat_comments = flatten_comments(comments)


# Run sentiment analysis
for comment in flat_comments:
    body = comment.get("commentBody") or ""
    sentiment = analyzer.polarity_scores(body)
    comment["sentiment"] = sentiment 


# Example: print the results
for comment in flat_comments:
    print(f"Comment: {comment['commentBody']}")
    print(f"Sentiment: {comment['sentiment']}")
    print(f"Upvote: {comment['upvotes']}")
    print('-' * 60)



poscount = 0
negcount = 0
for comment in flat_comments:
    compound = comment['sentiment']['compound']
    if compound < 0:
        negcount += 1
    if compound >= 0.05:
        poscount += 1

total = poscount +negcount
pos = poscount/total
neg = negcount/total
print(pos)
print(neg)
print(total)
# Out:
# 2025-05-09 17:10:22.602 | SUCCESS  | __main__:scrape_post:73 - scraped 434 comments from the post https://www.reddit.com/r/eagles/comments/1ilwnz0/post_game_thread_super_bowl_champions_the_eagles/
# Comment: We are World Champs! Time to celebrate our second Lombardi!
# Sentiment: {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compound': 0.7955}
# Upvote: None
# ------------------------------------------------------------
# Comment: Jake Elliott made 4 FGs and then re-made 3 of them from 5 yards further away as a big "fuck you" to all of us and I love that for him.
# Sentiment: {'neg': 0.095, 'neu': 0.79, 'pos': 0.114, 'compound': 0.1779}
# Upvote: 751
# ------------------------------------------------------------
# Comment: Good. He showed up when it mattered most and hit one from 50 too
# Sentiment: {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.4404}
# Upvote: 147
# ------------------------------------------------------------
# Comment: Whatever the fuck ritual he was doing 5 hours before the game absolutely paid off. Good to have him back to his usual self for the biggest game
# Sentiment: {'neg': 0.107, 'neu': 0.796, 'pos': 0.097, 'compound': -0.0865}
# Upvote: 81
# ------------------------------------------------------------
# Comment: Carson really had to watch both his backups win Super Bowls from the sideline LMAO.
# Sentiment: {'neg': 0.0, 'neu': 0.493, 'pos': 0.507, 'compound': 0.9236}
# Upvote: 527
# ------------------------------------------------------------
# Comment: Life writes the best comedy 😂
# Sentiment: {'neg': 0.103, 'neu': 0.326, 'pos': 0.571, 'compound': 0.8625}
# Upvote: 64
# ------------------------------------------------------------
# Comment: The Eagles tend to pick the route that makes Matt Nagy and Carson Wentz the most miserable.
# Sentiment: {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.5413}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Not only that but Devonta, AJ, Carter & and DeJean all acquired with picks from trading Wentz 🤣
# Sentiment: {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.6486}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Mahomes vs. Fangio: 8-
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 429
# ------------------------------------------------------------
# Comment: They were bringing up that record all week, and Fangio put those goons to silence.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 102
# ------------------------------------------------------------
# Comment: and now i'll be silently gooning to this game
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 12
# ------------------------------------------------------------
# Comment: and now i'll be silently gooning to this game
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 12
# ------------------------------------------------------------
# Comment: They barely showed Kellen during the game. Kinda weird.
# Sentiment: {'neg': 0.15, 'neu': 0.85, 'pos': 0.0, 'compound': -0.1045}
# Upvote: 51
# ------------------------------------------------------------
# Comment: They barely showed our side at all lol. Just sad chiefs 95% of the time
# Sentiment: {'neg': 0.164, 'neu': 0.688, 'pos': 0.148, 'compound': -0.0772}
# Upvote: 13
# ------------------------------------------------------------
# Comment: They barely showed our side at all lol. Just sad chiefs 95% of the time
# Sentiment: {'neg': 0.164, 'neu': 0.688, 'pos': 0.148, 'compound': -0.0772}
# Upvote: 13
# ------------------------------------------------------------
# Comment: Fuck it Kellen go get your bag. I was annoyed before but idc now. Chiefs sold out to stop the run and we tore them apart in the air. Literally every player and coaching staff member was amazing this game.
# Sentiment: {'neg': 0.143, 'neu': 0.749, 'pos': 0.108, 'compound': 0.09}
# Upvote: 46
# ------------------------------------------------------------
# Comment: 2017 was a story book season. Just the right amount of adversity. A magical year.
# Sentiment: {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.4215}
# Upvote: 425
# ------------------------------------------------------------
# Comment: Best team on the planet and we just found out it wasn’t close. Fuck. Yes.
# Sentiment: {'neg': 0.156, 'neu': 0.536, 'pos': 0.308, 'compound': 0.5267}
# Upvote: 204
# ------------------------------------------------------------
# Comment: No seriously. I bitched all year but only because I KNEW we were better than every other team by a size able margin. Like, the only thing that could beat the Eagles were the Eagles playing down to competition
# Sentiment: {'neg': 0.049, 'neu': 0.726, 'pos': 0.225, 'compound': 0.8052}
# Upvote: 23
# ------------------------------------------------------------
# Comment: I’ve been saying… why not us next? Howie is a salary cap genius and our defense is so young. I see no reason why we can’t reload and run it back either. Incredibly talented team.
# Sentiment: {'neg': 0.056, 'neu': 0.814, 'pos': 0.13, 'compound': 0.4391}
# Upvote: 13
# ------------------------------------------------------------
# Comment: I’ve been saying… why not us next? Howie is a salary cap genius and our defense is so young. I see no reason why we can’t reload and run it back either. Incredibly talented team.
# Sentiment: {'neg': 0.056, 'neu': 0.814, 'pos': 0.13, 'compound': 0.4391}
# Upvote: 13
# ------------------------------------------------------------
# Comment: No seriously. I bitched all year but only because I KNEW we were better than every other team by a size able margin. Like, the only thing that could beat the Eagles were the Eagles playing down to competition
# Sentiment: {'neg': 0.049, 'neu': 0.726, 'pos': 0.225, 'compound': 0.8052}
# Upvote: 23
# ------------------------------------------------------------
# Comment: I’ve been saying… why not us next? Howie is a salary cap genius and our defense is so young. I see no reason why we can’t reload and run it back either. Incredibly talented team.
# Sentiment: {'neg': 0.056, 'neu': 0.814, 'pos': 0.13, 'compound': 0.4391}
# Upvote: 13
# ------------------------------------------------------------
# Comment: I’ve been saying… why not us next? Howie is a salary cap genius and our defense is so young. I see no reason why we can’t reload and run it back either. Incredibly talented team.
# Sentiment: {'neg': 0.056, 'neu': 0.814, 'pos': 0.13, 'compound': 0.4391}
# Upvote: 13
# ------------------------------------------------------------
# Comment: We got what we deserved this team was too talented to not bring it home we are where we’re supposed to be
# Sentiment: {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.5106}
# Upvote: 64
# ------------------------------------------------------------
# Comment: I was thinking the same thing in the 3rd quarter. This team was just waiting for the game to end. Crazy.
# Sentiment: {'neg': 0.107, 'neu': 0.893, 'pos': 0.0, 'compound': -0.34}
# Upvote: 35
# ------------------------------------------------------------
# Comment: Just enjoy this everyone. We may win again next year, we may not. But this is such a special moment in all of our lives, don’t take it for granted.
# Sentiment: {'neg': 0.0, 'neu': 0.711, 'pos': 0.289, 'compound': 0.8608}
# Upvote: 380
# ------------------------------------------------------------
# Comment: I’ll never will
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 49
# ------------------------------------------------------------
# Comment: 2023 taught us that winning 1 score games doesn't mean anything
# Sentiment: {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.5267}
# Upvote: 314
# ------------------------------------------------------------
# Comment: 2023 taught us that winning 1 score games doesn't mean anything
# Sentiment: {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.5267}
# Upvote: 107
# ------------------------------------------------------------
# Comment: The Chiefs this year really did feel like the Eagles of last year. Something had to give.
# Sentiment: {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.4144}
# Upvote: 51
# ------------------------------------------------------------
# Comment: I shit you not, 2023 is exactly why I wasn’t worried about the Chiefs. I was worried about the Eagles not playing their best, but I was NEVER worried about the Chiefs. They looked so fraudulent and not a single team in the AFC looked good enough to capitalize on that
# Sentiment: {'neg': 0.23, 'neu': 0.674, 'pos': 0.097, 'compound': -0.7559}
# Upvote: 18
# ------------------------------------------------------------
# Comment: The Chiefs this year really did feel like the Eagles of last year. Something had to give.
# Sentiment: {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.4144}
# Upvote: 51
# ------------------------------------------------------------
# Comment: I shit you not, 2023 is exactly why I wasn’t worried about the Chiefs. I was worried about the Eagles not playing their best, but I was NEVER worried about the Chiefs. They looked so fraudulent and not a single team in the AFC looked good enough to capitalize on that
# Sentiment: {'neg': 0.23, 'neu': 0.674, 'pos': 0.097, 'compound': -0.7559}
# Upvote: 18
# ------------------------------------------------------------
# Comment: Chiefs are still 17-1 in one score games
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 13
# ------------------------------------------------------------
# Comment: Saquon broke the all time rushing record for both regular and post season.
# Sentiment: {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.4215}
# Upvote: 289
# ------------------------------------------------------------
# Comment: One of the best teams in the history of the league. This team will be mentioned forever as one of the most dominant SB performances that ever occurred.
# Sentiment: {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.6369}
# Upvote: 70
# ------------------------------------------------------------
# Comment: Literally no complaints. Fucking ass whooping and to me, this vindicates what we all knew in 2022. That field, and Gannon, fucked us over.
# Sentiment: {'neg': 0.245, 'neu': 0.598, 'pos': 0.157, 'compound': -0.604}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Literally no complaints. Fucking ass whooping and to me, this vindicates what we all knew in 2022. That field, and Gannon, fucked us over.
# Sentiment: {'neg': 0.245, 'neu': 0.598, 'pos': 0.157, 'compound': -0.604}
# Upvote: 14
# ------------------------------------------------------------
# Comment: THE CHIEFS JUST GOT PICKLED
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 285
# ------------------------------------------------------------
# Comment: THE CHIEFS JUST GOT PICKLED
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 20
# ------------------------------------------------------------
# Comment: 🗣️🗣️🗣️ PUT HOWIE IN THE HOF
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 244
# ------------------------------------------------------------
# Comment: We dumped gatorade with three minutes to go lmfao
# Sentiment: {'neg': 0.205, 'neu': 0.53, 'pos': 0.265, 'compound': 0.2023}
# Upvote: 57
# ------------------------------------------------------------
# Comment: We put in our second string QB and had him throw it on 4th down just ‘cause.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 33
# ------------------------------------------------------------
# Comment: We put in our second string QB and had him throw it on 4th down just ‘cause.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 33
# ------------------------------------------------------------
# Comment: Jalen haters in shambles. You might not think he’s the best, sometimes he makes bad decisions, but this guy fucking WINS
# Sentiment: {'neg': 0.142, 'neu': 0.557, 'pos': 0.301, 'compound': 0.7807}
# Upvote: 189
# ------------------------------------------------------------
# Comment: 3 best games of his career: super bowl 57, NFCC '25, super bowl 59. Dude balls when it matters most
# Sentiment: {'neg': 0.0, 'neu': 0.55, 'pos': 0.45, 'compound': 0.9201}
# Upvote: 57
# ------------------------------------------------------------
# Comment: Outside of one pass he played a perfect game.
# Sentiment: {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'compound': 0.7269}
# Upvote: 29
# ------------------------------------------------------------
# Comment: And that one pass was basically an arm punt
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 40
# ------------------------------------------------------------
# Comment: And that one pass was basically an arm punt
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 40
# ------------------------------------------------------------
# Comment: Just win baby! And he’s going to get the MVP trophy.
# Sentiment: {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.6239}
# Upvote: 13
# ------------------------------------------------------------
# Comment: That Hurts Jordan commercial was fucking TOUGHHHHHH
# Sentiment: {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}
# Upvote: 185
# ------------------------------------------------------------
# Comment: Thank you Eagles bros 🙏🛐. You've saved us all from 2 different 3-peats 🥹
# Sentiment: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7579}
# Upvote: 30
# ------------------------------------------------------------
# Comment: 2017 caught lightning in a bottle but this is the best Eagles team of my life
# Sentiment: {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.7783}
# Upvote: 174
# ------------------------------------------------------------
# Comment: Easily. There's an argument that this is one of the best teams in NFL history. We curbstomped good teams to get here.
# Sentiment: {'neg': 0.083, 'neu': 0.6, 'pos': 0.317, 'compound': 0.7906}
# Upvote: 60
# ------------------------------------------------------------
# Comment: One of the scariest rosters from top to bottom and they lived up the hype
# Sentiment: {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.2023}
# Upvote: 27
# ------------------------------------------------------------
# Comment: One of the scariest rosters from top to bottom and they lived up the hype
# Sentiment: {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.2023}
# Upvote: 27
# ------------------------------------------------------------
# Comment: It is not lost on me that I’ve gotten to see two Eagles Super Bowl wins when so many of our fans throughout the years did not live to this point. So fortunate to be here and see our team succeed at the highest level multiple times.
# Sentiment: {'neg': 0.0, 'neu': 0.718, 'pos': 0.282, 'compound': 0.9477}
# Upvote: 159
# ------------------------------------------------------------
# Comment: It’s insane, we’re really living in the golden era of Eagles history
# Sentiment: {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}
# Upvote: 55
# ------------------------------------------------------------
# Comment: Was just thinking about the
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 36
# ------------------------------------------------------------
# Comment:  boutta smell like bitch in here
# Sentiment: {'neg': 0.369, 'neu': 0.388, 'pos': 0.243, 'compound': -0.3182}
# Upvote: 164
# ------------------------------------------------------------
# Comment: I feel like 95% of them wanted the eagles to win lol
# Sentiment: {'neg': 0.0, 'neu': 0.497, 'pos': 0.503, 'compound': 0.8442}
# Upvote: 53
# ------------------------------------------------------------
# Comment: They did. But at the end of the day they still hate us.
# Sentiment: {'neg': 0.296, 'neu': 0.704, 'pos': 0.0, 'compound': -0.7227}
# Upvote: 24
# ------------------------------------------------------------
# Comment: I’m not an eagles fan 😅 but I like Jalen and saquon so you had all my support. Down vote if you want I’m not gonna lie
# Sentiment: {'neg': 0.041, 'neu': 0.685, 'pos': 0.274, 'compound': 0.8186}
# Upvote: 13
# ------------------------------------------------------------
# Comment: I’m not an eagles fan 😅 but I like Jalen and saquon so you had all my support. Down vote if you want I’m not gonna lie
# Sentiment: {'neg': 0.041, 'neu': 0.685, 'pos': 0.274, 'compound': 0.8186}
# Upvote: 13
# ------------------------------------------------------------
# Comment: They did. But at the end of the day they still hate us.
# Sentiment: {'neg': 0.296, 'neu': 0.704, 'pos': 0.0, 'compound': -0.7227}
# Upvote: 24
# ------------------------------------------------------------
# Comment: I’m not an eagles fan 😅 but I like Jalen and saquon so you had all my support. Down vote if you want I’m not gonna lie
# Sentiment: {'neg': 0.041, 'neu': 0.685, 'pos': 0.274, 'compound': 0.8186}
# Upvote: 13
# ------------------------------------------------------------
# Comment: I’m not an eagles fan 😅 but I like Jalen and saquon so you had all my support. Down vote if you want I’m not gonna lie
# Sentiment: {'neg': 0.041, 'neu': 0.685, 'pos': 0.274, 'compound': 0.8186}
# Upvote: 13
# ------------------------------------------------------------
# Comment: Hurts has outplayed Pat in the bowl twice now
# Sentiment: {'neg': 0.279, 'neu': 0.721, 'pos': 0.0, 'compound': -0.4767}
# Upvote: 135
# ------------------------------------------------------------
# Comment: No more Sirianni or Hurts slander will be tolerated ever. Ever.
# Sentiment: {'neg': 0.382, 'neu': 0.618, 'pos': 0.0, 'compound': -0.6771}
# Upvote: 123
# ------------------------------------------------------------
# Comment: Nah they are going to be Eagles legends forever. Hurts is a winner flat out.
# Sentiment: {'neg': 0.222, 'neu': 0.591, 'pos': 0.187, 'compound': 0.0772}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Glad he didn’t get fired after last season
# Sentiment: {'neg': 0.286, 'neu': 0.476, 'pos': 0.238, 'compound': -0.1531}
# Upvote: 12
# ------------------------------------------------------------
# Comment: Best Eagles team in history.
# Sentiment: {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.6369}
# Upvote: 121
# ------------------------------------------------------------
# Comment: 95 points between the SB and NFCC.  Just insane.
# Sentiment: {'neg': 0.252, 'neu': 0.748, 'pos': 0.0, 'compound': -0.4019}
# Upvote: 53
# ------------------------------------------------------------
# Comment: The Chiefs didn’t cross midfield until it was 34-0. What a beat down! Somebody wake me up
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 116
# ------------------------------------------------------------
# Comment: This. Broad street bullied!
# Sentiment: {'neg': 0.594, 'neu': 0.406, 'pos': 0.0, 'compound': -0.6588}
# Upvote: 13
# ------------------------------------------------------------
# Comment: THE EAGLES WON 2 SUPER BOWLS UPVOTE PARTY!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!LETS GOOOOOOOOOOOOO BIRDS!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Sentiment: {'neg': 0.0, 'neu': 0.439, 'pos': 0.561, 'compound': 0.9049}
# Upvote: 103
# ------------------------------------------------------------
# Comment: I'm sitting all alone in my house in rural Poland. It's 4:25 am and I still cannot process what I just watched. It's just hitting me now.
# Sentiment: {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.25}
# Upvote: 101
# ------------------------------------------------------------
# Comment: I am in Switzelrand after watching the German broadcast (born in Philly) and I am wondering if the Swiss have ever needed to grease the poles.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 20
# ------------------------------------------------------------
# Comment: Andy Reid finally coached an Eagles Super Bowl win.
# Sentiment: {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.8271}
# Upvote: 98
# ------------------------------------------------------------
# Comment: The folks who said that can STFU
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 98
# ------------------------------------------------------------
# Comment: I was one of them. I will eat humble pie.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 13
# ------------------------------------------------------------
# Comment: Hey at least you admit it big ups for that
# Sentiment: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Hey at least you admit it big ups for that
# Sentiment: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}
# Upvote: 14
# ------------------------------------------------------------
# Comment: The Love, Hurts spot was great. He was so disrespected this season by media.
# Sentiment: {'neg': 0.276, 'neu': 0.396, 'pos': 0.329, 'compound': 0.3256}
# Upvote: 85
# ------------------------------------------------------------
# Comment: "Mahomes was so bad in a SB that 2 of his TDs were in garbage time"
# Sentiment: {'neg': 0.23, 'neu': 0.77, 'pos': 0.0, 'compound': -0.6696}
# Upvote: 84
# ------------------------------------------------------------
# Comment: Chiefs fan here, congrats to you guys. Much better fanbase than people say and likable and great team that kicked our ass
# Sentiment: {'neg': 0.105, 'neu': 0.512, 'pos': 0.383, 'compound': 0.8481}
# Upvote: 80
# ------------------------------------------------------------
# Comment: Thanks best of luck next season 🫡
# Sentiment: {'neg': 0.0, 'neu': 0.284, 'pos': 0.716, 'compound': 0.8779}
# Upvote: 35
# ------------------------------------------------------------
# Comment: Good luck next year and thanks for coming over and congratulating.
# Sentiment: {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.8316}
# Upvote: 14
# ------------------------------------------------------------
# Comment: JAKE ELLIOT REDEMPTION, FUCK YOUR FLAGS HE'LL DO IT AGAIN
# Sentiment: {'neg': 0.28, 'neu': 0.72, 'pos': 0.0, 'compound': -0.5423}
# Upvote: 76
# ------------------------------------------------------------
# Comment: Jalen hurts is the best quarterback in the NFL. I’m sorry for doubting him. I’m sorry for doubting Sirianni.
# Sentiment: {'neg': 0.379, 'neu': 0.469, 'pos': 0.152, 'compound': -0.5106}
# Upvote: 65
# ------------------------------------------------------------
# Comment: THAT ONE WAS FOR YOU AMERICA
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 66
# ------------------------------------------------------------
# Comment: The absolute best part about BOTH Super Bowl wins is that the Eagles beat the best of the best, BOTH TIMES. Nobody can say "it was just <insert team>".
# Sentiment: {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.969}
# Upvote: 57
# ------------------------------------------------------------
# Comment: In November I contemplated suicide. This team grounded me to reality. I over came everything and the best team in football just won the championship. WE did it. Yes, I know I'm not on the team, but fuck it, WE ALL DID THIS! GO BIRDS!!!!!
# Sentiment: {'neg': 0.133, 'neu': 0.691, 'pos': 0.176, 'compound': -0.4438}
# Upvote: 59
# ------------------------------------------------------------
# Comment: BG goes out a champion. Unreal.
# Sentiment: {'neg': 0.0, 'neu': 0.562, 'pos': 0.438, 'compound': 0.5994}
# Upvote: 61
# ------------------------------------------------------------
# Comment: Hung 40 on the Pats and KC in the SuperBowl and won both.
# Sentiment: {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.5719}
# Upvote: 62
# ------------------------------------------------------------
# Comment: Pretty simple recipe. Just score 40 in the super bowl and you'll win.
# Sentiment: {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'compound': 0.8979}
# Upvote: 12
# ------------------------------------------------------------
# Comment: Kellen Moore best of luck to ya. On another note, fuck Jonathan Gannon
# Sentiment: {'neg': 0.169, 'neu': 0.483, 'pos': 0.348, 'compound': 0.5719}
# Upvote: 53
# ------------------------------------------------------------
# Comment: The only disappointment is that saquon didn’t get a long Td run. He deserved one.
# Sentiment: {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'compound': -0.5106}
# Upvote: 54
# ------------------------------------------------------------
# Comment: Chiefs sold out to stop him…. And got absolutely smashed just like every team that tried it (Steelers, Cleveland)
# Sentiment: {'neg': 0.1, 'neu': 0.774, 'pos': 0.126, 'compound': 0.144}
# Upvote: 31
# ------------------------------------------------------------
# Comment: CARSON WENTZ GOT TO WATCH BOTH OF OUR SUPERBOWL WINS FROM THE SIDELINES. Interesting…
# Sentiment: {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.6633}
# Upvote: 47
# ------------------------------------------------------------
# Comment: That score doesn't reflect the domination.
# Sentiment: {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.0382}
# Upvote: 49
# ------------------------------------------------------------
# Comment: Ok that Hurts commercial kinda ruled.
# Sentiment: {'neg': 0.333, 'neu': 0.43, 'pos': 0.237, 'compound': -0.2263}
# Upvote: 47
# ------------------------------------------------------------
# Comment: Jalen hurts slander is now illegal
# Sentiment: {'neg': 0.626, 'neu': 0.374, 'pos': 0.0, 'compound': -0.7717}
# Upvote: 51
# ------------------------------------------------------------
# Comment: Pickett has more rings and super bowl snaps than Allen, Prescott, and Lamar combined. Don't let anyone forget that.
# Sentiment: {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.7031}
# Upvote: 44
# ------------------------------------------------------------
# Comment: Did he just say "let's run this shit back?"
# Sentiment: {'neg': 0.347, 'neu': 0.653, 'pos': 0.0, 'compound': -0.6428}
# Upvote: 41
# ------------------------------------------------------------
# Comment: How Hurts ain’t up there shouting at the media is wild to me. Such restraint. I’d be petty af yo haha
# Sentiment: {'neg': 0.189, 'neu': 0.695, 'pos': 0.116, 'compound': -0.2263}
# Upvote: 41
# ------------------------------------------------------------
# Comment: That jalen commercial was cold
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 36
# ------------------------------------------------------------
# Comment: INJECT THAT JORDAN COMMERCIAL INTO MY VEINS
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 41
# ------------------------------------------------------------
# Comment: Today we:
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 37
# ------------------------------------------------------------
# Comment: Jalen winning MVP is just another level of satisfaction. This win is so special
# Sentiment: {'neg': 0.0, 'neu': 0.42, 'pos': 0.58, 'compound': 0.9299}
# Upvote: 37
# ------------------------------------------------------------
# Comment: So many storylines, young blood making plays, Brandon graham battling through it, Jalen smashing the haters, Jake kicking dimes, love this team
# Sentiment: {'neg': 0.18, 'neu': 0.61, 'pos': 0.21, 'compound': 0.2263}
# Upvote: 34
# ------------------------------------------------------------
# Comment: Shout out Jake Elliot man he didn’t even miss a single field goal even the ones that got called back
# Sentiment: {'neg': 0.078, 'neu': 0.922, 'pos': 0.0, 'compound': -0.1531}
# Upvote: 36
# ------------------------------------------------------------
# Comment: They were so worried about saquon they forgot to plan for everyone else. Go birds
# Sentiment: {'neg': 0.17, 'neu': 0.83, 'pos': 0.0, 'compound': -0.4341}
# Upvote: 38
# ------------------------------------------------------------
# Comment: This is genuinely why the Eagles offense is so good. It's possible to shut down Saquon, but not without opening up big pass opportunities or Hurts runs. And if you let up on Saquon at all, even for a single snap, he will make you pay for it.
# Sentiment: {'neg': 0.13, 'neu': 0.771, 'pos': 0.099, 'compound': -0.191}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Birds championships COUNT
# Sentiment: {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.4939}
# Upvote: 36
# ------------------------------------------------------------
# Comment: THAT GAME WASNT A SUPER BOWL. IT WAS A PHILLY PARTY IN FRONT OF AMERICA!!! I LOVE ALL YOU OF SICK MUGS!!! GO BIRDS!!!! THIS TEAM LIVES FOREVER!!!!!
# Sentiment: {'neg': 0.167, 'neu': 0.623, 'pos': 0.209, 'compound': 0.3863}
# Upvote: 34
# ------------------------------------------------------------
# Comment: Do not let the final score fool you…. We destroyed them. I can’t believe it.
# Sentiment: {'neg': 0.319, 'neu': 0.681, 'pos': 0.0, 'compound': -0.7269}
# Upvote: 28
# ------------------------------------------------------------
# Comment: This was the sweetest revenge ever! It feels so good to leave no room for narratives or goofy media spin because of how bad of an ass kicking it was.
# Sentiment: {'neg': 0.341, 'neu': 0.57, 'pos': 0.089, 'compound': -0.863}
# Upvote: 30
# ------------------------------------------------------------
# Comment: Bills Fans 🤝 Eagles Fans
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 30
# ------------------------------------------------------------
# Comment: Would it be hyperbole to say this is the best Eagles team of all time?
# Sentiment: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.6369}
# Upvote: 31
# ------------------------------------------------------------
# Comment: No. Best ever. By a mile
# Sentiment: {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
# Upvote: 12
# ------------------------------------------------------------
# Comment: 6 sacks without the blitz is tough
# Sentiment: {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.128}
# Upvote: 29
# ------------------------------------------------------------
# Comment: Hurts in the playoffs:
# Sentiment: {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# Upvote: 29
# ------------------------------------------------------------
# Comment: What happens when the Chiefs stop Saquon? The Eagles drop 40
# Sentiment: {'neg': 0.323, 'neu': 0.677, 'pos': 0.0, 'compound': -0.5106}
# Upvote: 34
# ------------------------------------------------------------
# Comment: the only thing that is going to make this super bowl better is when the team votes to not go to the white house
# Sentiment: {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.8188}
# Upvote: 30
# ------------------------------------------------------------
# Comment: Please inject 5 gallons of Mahomes facial expressions into my veins
# Sentiment: {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.3182}
# Upvote: 34
# ------------------------------------------------------------
# Comment: I wrote this during the wild card game seeing the vitriol in
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 29
# ------------------------------------------------------------
# Comment: While Saquon didn't have any flashy plays today his mere presence put holes in the Chiefs defense to open up the passing game.
# Sentiment: {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}
# Upvote: 30
# ------------------------------------------------------------
# Comment: He did have a clutch near the endzone catch earlier though.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 13
# ------------------------------------------------------------
# Comment: Yep. Them selling out to stop the run is what really fucked them.
# Sentiment: {'neg': 0.361, 'neu': 0.524, 'pos': 0.115, 'compound': -0.6901}
# Upvote: 11
# ------------------------------------------------------------
# Comment: It’s so late. No one’s gonna read this but I was just an absolute sobbing mess in 2018 when we won our first kne. It was just so close and then Brady was on that drive it just seemed like it was going to be stolen at the last second again. Then the pressure just released and we won! And I broke completely down.
# Sentiment: {'neg': 0.222, 'neu': 0.626, 'pos': 0.152, 'compound': -0.6287}
# Upvote: 28
# ------------------------------------------------------------
# Comment: That was an absolute BEATDOWN on the NFL’s favorite child. This Eagles team will go down as the greatest we’ve ever seen . Complete team top to bottom.
# Sentiment: {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.8402}
# Upvote: 29
# ------------------------------------------------------------
# Comment: Jordan with a fucking banger of a Jalen Hurts ad
# Sentiment: {'neg': 0.256, 'neu': 0.744, 'pos': 0.0, 'compound': -0.4767}
# Upvote: 29
# ------------------------------------------------------------
# Comment: I thought we would win convincingly.  I didn’t think it would be a complete and utter ass kicking.
# Sentiment: {'neg': 0.151, 'neu': 0.595, 'pos': 0.254, 'compound': 0.3832}
# Upvote: 25
# ------------------------------------------------------------
# Comment: Walking home from a friends place it’s 4:42 am here in Germany, I have to be up in 2h go fucking birds
# Sentiment: {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'compound': 0.4767}
# Upvote: 27
# ------------------------------------------------------------
# Comment: If someone told me Saturday that Mahommes would have the ball with two minutes left I would’ve shit my pants. Turns out it didn’t even matter. Total domination.
# Sentiment: {'neg': 0.163, 'neu': 0.801, 'pos': 0.035, 'compound': -0.6115}
# Upvote: 24
# ------------------------------------------------------------
# Comment: Best Eagle team of all time?
# Sentiment: {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
# Upvote: 25
# ------------------------------------------------------------
# Comment: A lot of talk on the broadcast about the Chiefs doing a good job on Barkley. But any team
# Sentiment: {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.2382}
# Upvote: 25
# ------------------------------------------------------------
# Comment: ESPN currently has Coop, Bark, and Hurts for interviews. They brought out a birthday cake for Coop and Bark. What a night.
# Sentiment: {'neg': 0.129, 'neu': 0.871, 'pos': 0.0, 'compound': -0.4767}
# Upvote: 28
# ------------------------------------------------------------
# Comment: It just hit me. This defense isn't changing much for the next several years. You guys. This may be a era of domination from the Eagles defense.
# Sentiment: {'neg': 0.042, 'neu': 0.847, 'pos': 0.11, 'compound': 0.2323}
# Upvote: 24
# ------------------------------------------------------------
# Comment: IT WAS 40-6 WITH 4 MINUTES TO GO WE FUCKING BLEW THEM OUT LETS GOOOOOO
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 26
# ------------------------------------------------------------
# Comment: I'm gonna need to consult my doctor in 3 hours if this erection doesn't go away
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 27
# ------------------------------------------------------------
# Comment: Kenny Pickett took snaps in the Super Bowl before Dak
# Sentiment: {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.5994}
# Upvote: 26
# ------------------------------------------------------------
# Comment: As far as I’m concerned they won 34-0
# Sentiment: {'neg': 0.0, 'neu': 0.654, 'pos': 0.346, 'compound': 0.5719}
# Upvote: 25
# ------------------------------------------------------------
# Comment: Jake Elliot was a stud tonight. Showed up when it really mattered.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 28
# ------------------------------------------------------------
# Comment: Freaking Matt Stafford put up more of a fight than Mahomes did.
# Sentiment: {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'compound': -0.6872}
# Upvote: 26
# ------------------------------------------------------------
# Comment: Shout out to Nakobe Dean. He played his ass off this year and was a huge reason for the team’s  success. Sucks he couldn’t be on the field for the big victory but he was important nonetheless.
# Sentiment: {'neg': 0.093, 'neu': 0.723, 'pos': 0.184, 'compound': 0.4404}
# Upvote: 26
# ------------------------------------------------------------
# Comment: You want to know how and why this Eagles team is the best team?
# Sentiment: {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.6705}
# Upvote: 24
# ------------------------------------------------------------
# Comment: We put our backups in. In the Super Bowl. Think about that.
# Sentiment: {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.5994}
# Upvote: 25
# ------------------------------------------------------------
# Comment: Kenny Pickett played.
# Kenny. Pickett.
# Sentiment: {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.34}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Pickett has more Superbowl snaps than Dak Prescott!!!!!
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Pickett has more Superbowl snaps than Dak Prescott!!!!!
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 14
# ------------------------------------------------------------
# Comment: I’m flying to Manila today via Newark with a layover in Tokyo and I’m so hungover I might puke in the security line.
# Sentiment: {'neg': 0.127, 'neu': 0.784, 'pos': 0.09, 'compound': -0.25}
# Upvote: 28
# ------------------------------------------------------------
# Comment: THE JALEN HURTS HATERS ARE QUIET TONIGHT
# Sentiment: {'neg': 0.558, 'neu': 0.442, 'pos': 0.0, 'compound': -0.743}
# Upvote: 23
# ------------------------------------------------------------
# Comment: Bills fan here.
# Sentiment: {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.3182}
# Upvote: 25
# ------------------------------------------------------------
# Comment: I remember after the last one, chiefs o-line wore shirts saying 0 sacks to their parade. I kinda wanna see something just as petty.
# Sentiment: {'neg': 0.073, 'neu': 0.927, 'pos': 0.0, 'compound': -0.2023}
# Upvote: 24
# ------------------------------------------------------------
# Comment: Nick Foles is a legend forever, but Jalen Hurts is officially the greatest eagles quarterback of all time
# Sentiment: {'neg': 0.16, 'neu': 0.617, 'pos': 0.224, 'compound': 0.3919}
# Upvote: 20
# ------------------------------------------------------------
# Comment: They stopped saquon, they forgot about Jalen
# Sentiment: {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'compound': -0.2263}
# Upvote: 22
# ------------------------------------------------------------
# Comment: There was a time when I thought I'd never see my team PLAY in a Super Bowl let alone win one. Now they have 2. Unreal.
# Sentiment: {'neg': 0.057, 'neu': 0.632, 'pos': 0.311, 'compound': 0.87}
# Upvote: 22
# ------------------------------------------------------------
# Comment: None
# Sentiment: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 19
# ------------------------------------------------------------
# Comment: THEY NOT LIKE US🦅🦅🦅
# Sentiment: {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'compound': -0.3924}
# Upvote: 23
# ------------------------------------------------------------
# Comment: Can’t wait to watch every espn show tomorrow where they all have to eat shit about the nonsense spewed about Jalen hurts
# Sentiment: {'neg': 0.331, 'neu': 0.669, 'pos': 0.0, 'compound': -0.8555}
# Upvote: 23
# ------------------------------------------------------------
# Comment: E-L-G-S-E-S ELGSES!
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 22
# ------------------------------------------------------------
# Comment: I am so incredibly proud of you guys!!!! You guys smoked them so hard!! It was a pleasure to watch :)
# Sentiment: {'neg': 0.061, 'neu': 0.559, 'pos': 0.38, 'compound': 0.8927}
# Upvote: 20
# ------------------------------------------------------------
# Comment: Best fucking Eagles team I've ever seen.  And BG gets a second ring!
# Sentiment: {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.6696}
# Upvote: 19
# ------------------------------------------------------------
# Comment: LET ME REMIND EVERYONE THAT JAKE THE MAKE MADE EVERY SINGLE KICK!!! GO BIRDS!!!!
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 22
# ------------------------------------------------------------
# Comment: That was fucking surreal. I knew they could win but didn't even dare DREAM of being able to unclench at the end of the third quarter.
# Sentiment: {'neg': 0.1, 'neu': 0.818, 'pos': 0.082, 'compound': -0.134}
# Upvote: 24
# ------------------------------------------------------------
# Comment: Who said fire Sirianni after week 4? (It was me I’m so sorry)
# Sentiment: {'neg': 0.274, 'neu': 0.726, 'pos': 0.0, 'compound': -0.4838}
# Upvote: 22
# ------------------------------------------------------------
# Comment: Scoring 40 points is pretty high in a Super Bowl. The last team to score in the 40s was…us when we won in 2018 with 41. Fuck yeah, go birds!
# Sentiment: {'neg': 0.084, 'neu': 0.598, 'pos': 0.318, 'compound': 0.8687}
# Upvote: 20
# ------------------------------------------------------------
# Comment: TWICE!!! I’VE LIVED LONG ENOUGH TO SEE THIS HAPPEN TWICE!!!
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 19
# ------------------------------------------------------------
# Comment: Barkley doesn’t have the stats this game, but he had the safeties playing 12 yards off the line of scrimmage and made the defense feel him every time he had the ball. He’s my MVP tonight
# Sentiment: {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.7351}
# Upvote: 18
# ------------------------------------------------------------
# Comment: I was here 2/9/2025 Eagles SB Champs in a blowout of KC
# Sentiment: {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.4215}
# Upvote: 23
# ------------------------------------------------------------
# Comment: Eagles absolutely dominated the postseason. Put of 55 on Washington, put up 40 and rested the starts in the Super Bowl. Wild.
# Sentiment: {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.5994}
# Upvote: 22
# ------------------------------------------------------------
# Comment: Saying the eagles would have to “play a perfect game” and then they spanked them like children
# Sentiment: {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.7351}
# Upvote: 10
# ------------------------------------------------------------
# Comment: The game wasn’t even as close as the Commanders game as far as how it looked.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 20
# ------------------------------------------------------------
# Comment: All those dumb mock drafts had us picking at 31
# Sentiment: {'neg': 0.433, 'neu': 0.567, 'pos': 0.0, 'compound': -0.7269}
# Upvote: 20
# ------------------------------------------------------------
# Comment: I knew it was ours when Coop had his pick six. Man what a night.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 19
# ------------------------------------------------------------
# Comment: Who else flipped their living room upside down on the Cooper DeJean pick 6?
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 18
# ------------------------------------------------------------
# Comment: BG going out on top makes me so happy sad
# Sentiment: {'neg': 0.2, 'neu': 0.414, 'pos': 0.387, 'compound': 0.4876}
# Upvote: 20
# ------------------------------------------------------------
# Comment: I am fucking so drunk and I love all you mother fuckers
# Sentiment: {'neg': 0.358, 'neu': 0.438, 'pos': 0.204, 'compound': -0.4878}
# Upvote: 20
# ------------------------------------------------------------
# Comment: Petition for the Mahomes strip sack to be known as the Fumblerooskie from now until the end of time. Thank you.
# Sentiment: {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.3612}
# Upvote: 22
# ------------------------------------------------------------
# Comment: Jake was clutch as ever tonight. Kept the momentum nailing those kicks.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 20
# ------------------------------------------------------------
# Comment: Every Super Bowl we play in we will need a Wentz on a bench. It’s the secret sauce.
# Sentiment: {'neg': 0.0, 'neu': 0.717, 'pos': 0.283, 'compound': 0.743}
# Upvote: 19
# ------------------------------------------------------------
# Comment: Shoutout Jake Ellliot
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 21
# ------------------------------------------------------------
# Comment: I'm so drunk
# Sentiment: {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'compound': -0.4005}
# Upvote: 19
# ------------------------------------------------------------
# Comment: Eagles have beaten Brady/Belichick and Mahomes/Reid in the Super Bowl.
# Sentiment: {'neg': 0.19, 'neu': 0.544, 'pos': 0.265, 'compound': 0.2732}
# Upvote: 24
# ------------------------------------------------------------
# Comment: Patrick Mahomes' top receiver in the first half was Cooper DeJean. He had 38 yards and a touchdown.
# Sentiment: {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.2023}
# Upvote: 22
# ------------------------------------------------------------
# Comment: My dad passed in December but I got to watch this one with my brother, my wife, and my two sons. Love you Dad, Go Birds 🦅
# Sentiment: {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.7783}
# Upvote: 22
# ------------------------------------------------------------
# Comment: So fucking happy for everyone. But to see Graham out there one last time and end his career on top. I could cry for the man.
# Sentiment: {'neg': 0.13, 'neu': 0.719, 'pos': 0.151, 'compound': -0.0809}
# Upvote: 21
# ------------------------------------------------------------
# Comment: Both of the Eagles SB’s have directly or indirectly stopped a 3 peat lol
# Sentiment: {'neg': 0.114, 'neu': 0.719, 'pos': 0.168, 'compound': 0.2263}
# Upvote: 22
# ------------------------------------------------------------
# Comment: Least stressful championship run ever. Just beating the shit out of teams week after week. lol
# Sentiment: {'neg': 0.114, 'neu': 0.417, 'pos': 0.47, 'compound': 0.8556}
# Upvote: 21
# ------------------------------------------------------------
# Comment: Guys, yes all the usual suspects were great. BUT AVONTE MADDOX PICKED ONE HELL OF A GAME TO BE IMPACTFUL!!
# Sentiment: {'neg': 0.324, 'neu': 0.53, 'pos': 0.146, 'compound': -0.8118}
# Upvote: 23
# ------------------------------------------------------------
# Comment: Xavier Worthy went 8/157/2 in the Super Bowl and I cannot possibly imagine a more fraudulent stat line than that. Did he even catch a ball before they were down 5 scores
# Sentiment: {'neg': 0.089, 'neu': 0.738, 'pos': 0.173, 'compound': 0.5118}
# Upvote: 22
# ------------------------------------------------------------
# Comment: Bills fan, thank you Birds. Legendary dismantling of the most annoying "dynasty" in NFL history
# Sentiment: {'neg': 0.151, 'neu': 0.606, 'pos': 0.243, 'compound': 0.204}
# Upvote: 22
# ------------------------------------------------------------
# Comment: Let it be known
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 21
# ------------------------------------------------------------
# Comment: Just want the recoord to show it was 40 to fucking 6 at one point 🤣
# Sentiment: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.5423}
# Upvote: 19
# ------------------------------------------------------------
# Comment: I don’t wanna hear shit about Jalen Hurts or Nick Sirianni ever again.
# Sentiment: {'neg': 0.379, 'neu': 0.621, 'pos': 0.0, 'compound': -0.7717}
# Upvote: 20
# ------------------------------------------------------------
# Comment: I don't know who needs to hear this, but the Eagles blew out the Chiefs so badly in the Super Bowl that they pulled their starters just to make sure everybody stayed healthy for next September.
# Sentiment: {'neg': 0.111, 'neu': 0.649, 'pos': 0.24, 'compound': 0.7479}
# Upvote: 22
# ------------------------------------------------------------
# Comment: Thank god we avoided the KC three-peat. The media would've been talking about it 24/7.
# Sentiment: {'neg': 0.126, 'neu': 0.632, 'pos': 0.242, 'compound': 0.296}
# Upvote: 19
# ...
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Let's run this shit back......
# Sentiment: {'neg': 0.515, 'neu': 0.485, 'pos': 0.0, 'compound': -0.6428}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Where are all the Hurts haters now!!! That D, holy fuck!!!
# Sentiment: {'neg': 0.578, 'neu': 0.422, 'pos': 0.0, 'compound': -0.8994}
# Upvote: 11
# ------------------------------------------------------------
# Comment: SUPER BOWL CHAMPIONS!!! WE WERE NOT GOING TO BE DENIED THIS TIME!!! PLAY THE FIGHT SONG ALL DAMN NIGHT!!!
# Sentiment: {'neg': 0.256, 'neu': 0.405, 'pos': 0.339, 'compound': 0.5673}
# Upvote: 10
# ------------------------------------------------------------
# Comment: FLY EAGLES FLY
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Doesn’t even feel real
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: SUPER BOWL FUCKING CHAMPIONS!
# Sentiment: {'neg': 0.0, 'neu': 0.202, 'pos': 0.798, 'compound': 0.8353}
# Upvote: 11
# ------------------------------------------------------------
# Comment: SUPER BOWL? WON.
# MERCH? ORDERED.
# BRICKED? UP.
# Sentiment: {'neg': 0.0, 'neu': 0.381, 'pos': 0.619, 'compound': 0.8458}
# Upvote: 10
# ------------------------------------------------------------
# Comment: Congratulations Eagles fans! :)
# Sentiment: {'neg': 0.0, 'neu': 0.218, 'pos': 0.782, 'compound': 0.8016}
# Upvote: 11
# ------------------------------------------------------------
# Comment: i don’t need to care that the phils have no plate discipline, i don’t need to care that embiid is held together by scotch tape, i just care that the EAGLES ARE TWO TIME CHAMPS BABYYYY
# Sentiment: {'neg': 0.047, 'neu': 0.669, 'pos': 0.283, 'compound': 0.8986}
# Upvote: 11
# ------------------------------------------------------------
# Comment: The end of the chiefs dynasty and the start of the Eagles Dynasty. This team has so much potential and this season was magical for so many reasons.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 12
# ------------------------------------------------------------
# Comment: We live in such a special time as Eagles fans. There was a point I thought I would never witness an Eagles SB win after so many heartbreaking losses in the playoffs; now we have 2 against two different legendary teams with this one being a complete domination from beginning to end. I’m still in disbelief.
# Sentiment: {'neg': 0.115, 'neu': 0.785, 'pos': 0.1, 'compound': 0.015}
# Upvote: 10
# ------------------------------------------------------------
# Comment: We beat Brady and Mahomes for our super bowls. Crazy!
# Sentiment: {'neg': 0.164, 'neu': 0.548, 'pos': 0.287, 'compound': 0.4199}
# Upvote: 12
# ------------------------------------------------------------
# Comment: I need to hear Merrill’s call to this game asap
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Jake Elliot is a stone cold killer.
# Sentiment: {'neg': 0.417, 'neu': 0.583, 'pos': 0.0, 'compound': -0.6486}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Cooper eating some cake leave the champ alone.
# Sentiment: {'neg': 0.283, 'neu': 0.442, 'pos': 0.274, 'compound': 0.2263}
# Upvote: 12
# ------------------------------------------------------------
# Comment: I can’t WAIT to hear Nick wrights mouth tomrorow.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 12
# ------------------------------------------------------------
# Comment: What an absolutely cathartic experience.. especially given how 57 went and left such a sour taste in our mouth. I fucking love this team.
# Sentiment: {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'compound': 0.6697}
# Upvote: 11
# ------------------------------------------------------------
# Comment: saquon lowkey a super great competitor. puts on a nice guy facade but that dude is wired to win. pretty much said they knew halfway through the week that the chiefs couldn't hang with them
# Sentiment: {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.9468}
# Upvote: 11
# ------------------------------------------------------------
# Comment: This team man. From being 2-2 and having a very rocky start, to being incredibly dominant the whole rest of the way. Go Birds!!! 🦅
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: I LOVE YOU ALL. GO FUCKING BIRDS!!!
# Sentiment: {'neg': 0.0, 'neu': 0.542, 'pos': 0.458, 'compound': 0.7249}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Someone send me pics on Broad!! I'm in the South🤣
# Sentiment: {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.5837}
# Upvote: 11
# ------------------------------------------------------------
# Comment: watched the various hurts interviews and think I really found a newfound respect for him as a person. he really is humble AF. everyone urging him to show out a bit after everyone was doubting him and he's not having it. just showing gratitude. love that he got the W over everyone in the end.
# Sentiment: {'neg': 0.083, 'neu': 0.756, 'pos': 0.16, 'compound': 0.7269}
# Upvote: 11
# ------------------------------------------------------------
# Comment: My mate is a fan but not a die-hard. He was watching with me tonight and was absolutely raging we gave up 22 points. He might have the bug.
# Sentiment: {'neg': 0.15, 'neu': 0.801, 'pos': 0.049, 'compound': -0.6586}
# Upvote: 12
# ------------------------------------------------------------
# Comment: Its still not sinking in that this was the Super Bowl omg this was such a brutal win it felt like dispatching the saints in week 3
# Sentiment: {'neg': 0.11, 'neu': 0.617, 'pos': 0.273, 'compound': 0.7269}
# Upvote: 11
# ------------------------------------------------------------
# Comment: THIS IS THE BEST DAY OF MY LIFE
# Sentiment: {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}
# Upvote: 12
# ------------------------------------------------------------
# Comment: Wonder if Travis Kelce finally got out that cry he was holding in since halftime.
# Sentiment: {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.4767}
# Upvote: 12
# ------------------------------------------------------------
# Comment: Since I moved to Hawai'i, the Eagles have won two Superbowls...I will never leave here. Celebrate Strong Philly. Watch out for my Old Man down there...he probably forgot he has a bum knee and back 😂🥹
# Sentiment: {'neg': 0.102, 'neu': 0.728, 'pos': 0.17, 'compound': 0.5023}
# Upvote: 9
# ------------------------------------------------------------
# Comment: Jonathan Gannon is a terrorist
# Sentiment: {'neg': 0.54, 'neu': 0.46, 'pos': 0.0, 'compound': -0.6908}
# Upvote: 10
# ------------------------------------------------------------
# Comment: Chiefs fan here, congrats Birds. 👏
# Sentiment: {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
# Upvote: 14
# ------------------------------------------------------------
# Comment: Can’t Rig the field can’t win. Back to back 3-peat defectors
# Sentiment: {'neg': 0.244, 'neu': 0.513, 'pos': 0.244, 'compound': 0.25}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Well done wrecking the Chiefs
# Sentiment: {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.2732}
# Upvote: 12
# ------------------------------------------------------------
# Comment: The final score does not show how much of a beat down it was. Eagles were up 34-0 at one point.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Congrats from Canada!! GO BIRDS FLY EAGLES FLY
# Sentiment: {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.6103}
# Upvote: 12
# ------------------------------------------------------------
# Comment: Let’s trade for Miles Garrett and go back to back.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: 2X CHAMPIONS I LOVE THE EAGLES BEST NIGHT OF MY LIFEEEEEE 🦅🦅🦅
# Sentiment: {'neg': 0.0, 'neu': 0.44, 'pos': 0.56, 'compound': 0.9432}
# Upvote: 11
# ------------------------------------------------------------
# Comment: RENT = PAID
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 12
# ------------------------------------------------------------
# Comment: People were so busy sucking off Spags that they overlooked Fangio
# Sentiment: {'neg': 0.099, 'neu': 0.901, 'pos': 0.0, 'compound': -0.0258}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Ya'll remember when Mahomes wore a midnight green suit coming to the game?
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 12
# ------------------------------------------------------------
# Comment: The whole country is bleeding green tonight, go birds! Also imagine being Barkley, getting traded from the giants and immediately winning a super bowl lmao
# Sentiment: {'neg': 0.0, 'neu': 0.657, 'pos': 0.343, 'compound': 0.9098}
# Upvote: 12
# ------------------------------------------------------------
# Comment: The Eagles now have multiple SBs like the rest of the NFC East and calling it now, gonna add to that total this time next year.
# Sentiment: {'neg': 0.143, 'neu': 0.776, 'pos': 0.081, 'compound': -0.4466}
# Upvote: 12
# ------------------------------------------------------------
# Comment: I forgot Q was on the field tonight
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 10
# ------------------------------------------------------------
# Comment: I love all yall. We’ve came some far since that heart attack win over GB in Brazil
# Sentiment: {'neg': 0.11, 'neu': 0.459, 'pos': 0.431, 'compound': 0.8779}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Do you think we’ll finally get the top spot in the power rankings?
# Sentiment: {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.2023}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Just want to throw out a shout to Josh Sweat. You came to play!!
# Sentiment: {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.508}
# Upvote: 12
# ------------------------------------------------------------
# Comment: The Kansas City Chiefs can still win the Super Bowl if Mike Pence has the courage to do the right thing
# Sentiment: {'neg': 0.0, 'neu': 0.623, 'pos': 0.377, 'compound': 0.8979}
# Upvote: 11
# ------------------------------------------------------------
# Comment: This whole game felt like an out of body experience. I live in Chiefs country. I am so fucking happy I don't have to deal with their fans talking shit for the next year at least 😂
# Sentiment: {'neg': 0.106, 'neu': 0.691, 'pos': 0.203, 'compound': 0.7245}
# Upvote: 11
# ------------------------------------------------------------
# Comment: KC in the 4th quarter with Garbage stats
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Jalen fuckin Hurts
# Sentiment: {'neg': 0.629, 'neu': 0.371, 'pos': 0.0, 'compound': -0.5256}
# Upvote: 10
# ------------------------------------------------------------
# Comment: Just a reminder, Nick is #1 in win percentage in all current head coach, and #5 overall in nfl history.
# Sentiment: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.5859}
# Upvote: 10
# ------------------------------------------------------------
# Comment: Vic Fangio:
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: I’m still like in shock. It’s like it went so well so quickly I didn’t let myself enjoy it out of fear that acknowledging it would kill the magic
# Sentiment: {'neg': 0.242, 'neu': 0.506, 'pos': 0.252, 'compound': -0.1428}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Dude I'm so ready for next season already. I want to watch this team more!
# Sentiment: {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.5904}
# Upvote: 11
# ------------------------------------------------------------
# Comment: All season we were on the edge of our seats. Who would have thought that the most relaxing games of the season would be the NFCCG and the frickin’ Suoer Bowl?
# Sentiment: {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.5413}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Most dominant Philly championship performance since the 83 Sixers.
# Sentiment: {'neg': 0.0, 'neu': 0.717, 'pos': 0.283, 'compound': 0.4877}
# Upvote: 11
# ------------------------------------------------------------
# Comment: The second I saw how locked in the Eagles looked I their SB week photos and how happy-go-lucky the Chiefs looked in theirs, I knew deep down it was over
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Dude jalyx hunt was amazing!
# Sentiment: {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.6239}
# Upvote: 11
# ------------------------------------------------------------
# Comment: This Eagles defense needs a nickname. What should it be?
# Sentiment: {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.128}
# Upvote: 12
# ------------------------------------------------------------
# Comment: You just know some degenerate but a ton of money on Jahan Dotson to be the first score and he almost got it.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Shout out to Matthew Stafford. He stays a super underrated QB and had me sweating in the divisional for a bit there. Only QB this postseason to start to figure out the defensive scheme, even if it did come pretty late in the game
# Sentiment: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.802}
# Upvote: 11
# ------------------------------------------------------------
# Comment: This was a win for the other America and I fucking love it.
# Sentiment: {'neg': 0.0, 'neu': 0.57, 'pos': 0.43, 'compound': 0.8516}
# Upvote: 11
# ------------------------------------------------------------
# Comment: Giants fan here- congratulations on your second win, but a bigger congrats to Saquon for a historic season and a ring
# Sentiment: {'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'compound': 0.8779}
# Upvote: 11
# ------------------------------------------------------------
# Comment: None
# Sentiment: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 10
# ------------------------------------------------------------
# Comment: Jalen didnt know what to do with his hands 🙌
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Upvote: 9
# ------------------------------------------------------------
# Comment: 2-2 to SB Champs.
# Sentiment: {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.4215}
# Upvote: 10
# ------------------------------------------------------------
# Comment: thank you so much for ending the long national nightmare and defeating the evil empire!!! it was a joy to be an eagles fan for these past 2 weeks 🫡
# Sentiment: {'neg': 0.169, 'neu': 0.603, 'pos': 0.228, 'compound': 0.3561}
# Upvote: 10
# ------------------------------------------------------------
# Comment: I love you Philadelphia. I love you Eagles. I only wish my dad was here. DOMINATION. GLORIOUS FUCKING DOMINATION. Best birthday present I can ever get.
# Sentiment: {'neg': 0.108, 'neu': 0.421, 'pos': 0.47, 'compound': 0.9602}
# Upvote: 10
# ------------------------------------------------------------
# 0.6795180722891566
# 0.3204819277108434
# 415
